# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
plt.rcParams["svg.fonttype"] = "none"
import matplotlib.patches as mpatches
from scipy.stats import ttest_ind, mannwhitneyu

# %%
semi_naive_deseq = pd.read_csv('Data/deseq2_results_tables/semi_naive_vs_control_naive_deseq.tsv', sep="\t")

expressed_genes_set = set(semi_naive_deseq['gene_id'])
print("length of expressed_genes_set: ", len(expressed_genes_set))

transcript_data = []

with open('genomes/genome_m39/gencode.vM27.chr_patch_hapl_scaff.annotation.gtf', 'r') as gtf_file:
    for line in gtf_file:
        if line.startswith('#'):
            continue

        columns = line.strip().split('\t')
        attributes = columns[8]

        if 'transcript_id' in attributes:
            gene_name = [field for field in attributes.split(';') if 'gene_name' in field][0]
            gene_name = gene_name.split('"')[1]
            gene_id = [field for field in attributes.split(';') if 'gene_id' in field][0]
            gene_id = gene_id.split('"')[1]
            transcript_id = [field for field in attributes.split(';') if 'transcript_id' in field][0]
            transcript_id = transcript_id.split('"')[1]
            gene_type = [field for field in attributes.split(';') if 'gene_type' in field][0]
            gene_type = gene_type.split('"')[1]

            transcript_data.append(columns[:7] + [gene_id] + [gene_name] + [transcript_id] + [gene_type])

column_names = ['seqname', 'source', 'feature', 'start', 'end', 'score', "strand", "gene_id", "gene_name", 'transcript_id', 'gene_type']

annotation = pd.DataFrame(transcript_data, columns=column_names)
annotation['start'] = annotation['start'].astype(int) - 1
annotation = annotation[annotation['feature'] == 'transcript']

gene_id_to_name = dict(zip(annotation['gene_id'], annotation['gene_name']))

expressed_gene_names_set = set([gene_id_to_name[gene_id] for gene_id in expressed_genes_set])
expressed_gene_names_set
# Out:
# length of expressed_genes_set:  16484
# {'Rabl2',
#  'Cpeb1',
#  'Oas1a',
#  'Sulf2',
#  'Gm6316',
#  'Cyp1a1',
#  'Ube2w',
#  'Bmpr2',
#  'Gm13777',
#  'Smpd5',
#  'Rad52',
#  'Gm50390',
#  'Gm44835',
#  'Aldh7a1',
#  'Gm2436',
#  'Cspg4b',
#  'Amer1',
#  'B4galnt4',
#  '1700108F19Rik',
#  'Gon4l',
#  'Pafah1b2',
#  'Kank4os',
#  'Creb3l1',
#  'H2bc15',
#  'Klf2',
#  'Mdh1',
#  'Commd1',
#  'Pcyox1',
#  'Ssc4d',
#  'Smg5',
#  'Gm47817',
#  'Pik3c2a',
#  'Megf6',
#  'Tmem150a',
#  'Gm13092',
#  'Mgst1',
#  'Ube2v1',
#  'Traf7',
#  'Tmem265',
#  'Gm20900',
#  'Ubl3',
#  'Tbc1d8',
#  'Ppme1',
#  'Smox',
#  'Tcaf2',
#  'Nudt5',
#  'Gm38359',
#  'Tubb2a',
#  'Nxf3',
#  'Gm5529',
#  '3110040N11Rik',
#  'Rps2',
#  'Mcts1',
#  'Ltbr',
#  'Arid4b',
#  'Sri',
#  'Sncg',
#  'Rbm8a',
#  'Phpt1',
#  'Nfe2',
#  'Rnaseh2a',
#  'Lag3',
#  'Hdx',
#  'Pdp1',
#  'Fam3a',
#  'Gm26814',
#  'Srek1ip1',
#  'Apod',
#  'Hmgn2',
#  'Hs6st2',
#  'Calb2',
#  'Vim',
#  'Pomgnt1',
#  'Snord49b',
#  'Zfp3',
#  'Phactr2',
#  'Atad1',
#  'Gm43019',
#  'H2az1',
#  'Cwc27',
#  'Gm5525',
#  'Gm27680',
#  'Arid1a',
#  'Pkia',
#  'Mospd1',
#  'Thrap3',
#  'Eif5a',
#  'Gas5',
#  'Yeats2',
#  'Dcp1a',
#  '1700055D18Rik',
#  'Yipf3',
#  'Psmd8',
#  'Gm50367',
#  'Pip5k1b',
#  'Alyref2',
#  'Ndufs2',
#  'Riok1',
#  'Macroh2a1',
#  'Ccdc171',
#  'Gpr135',
#  '2810047C21Rik1',
#  'Vps13a',
#  'Gm5835',
#  'Wnt9a',
#  'Gm49493',
#  'Tfdp1',
#  'Ndufa13',
#  'Bex1',
#  'Prkaa1',
#  'Fam120a',
#  'Nutf2-ps1',
#  'Pdpk1',
#  'Obscn',
#  'Gli1',
#  'Abhd17a',
#  'Gm44597',
#  'Agpat1',
#  'Gm21926',
#  'Dbf4',
#  'B3gnt3',
#  'Mier2',
#  'Sphk2',
#  'Gm5801',
#  'Gm8258',
#  'Fbxo34',
#  'Romo1',
#  'Sp5',
#  'Mrpl57',
#  'Rpl31',
#  'Has3',
#  'Gm9732',
#  'Crb2',
#  'Clcn3',
#  'Frrs1',
#  'Gtf3c5',
#  'Kcnd1',
#  'Gm4349',
#  'Diras2',
#  'Oxld1',
#  'Gm45358',
#  'Lrch1',
#  '2700081O15Rik',
#  'Rnf121',
#  'Cenpa',
#  'Catsperg1',
#  'Gm5523',
#  'Gm45871',
#  'Fst',
#  'Gm37018',
#  'Rdh12',
#  'Gm13321',
#  'Gm6336',
#  'Hps6',
#  'Trmt112',
#  'Chd1l',
#  'Gm45694',
#  'Actg1',
#  'Emc8',
#  'Tyk2',
#  'Gm17068',
#  'Tstd2',
#  'Isca2',
#  'Erp29',
#  'Gm49376',
#  'Gas2l1',
#  'Rps27',
#  '5430414B19Rik',
#  'Mageb16-ps2',
#  'Alg1',
#  'Tdrp',
#  'Ncdn',
#  'Ssu72',
#  'Gm10416',
#  'Tsga10ip',
#  'Limd2',
#  'Wdr13',
#  'Mrm2',
#  'Gm43428',
#  'Trib3',
#  'Mfsd2b',
#  'Tmem181b-ps',
#  'Mars2',
#  'Rtl8a',
#  'Gm10340',
#  'Sel1l3',
#  'Fth-ps2',
#  'Hirip3',
#  'Serpine2',
#  'Zfp652',
#  'Spg20',
#  'Gm37639',
#  '5730409E04Rik',
#  'Plod1',
#  'Gad2',
#  'Lnpk',
#  'Zscan29',
#  'Clca4b',
#  'Rab34',
#  'Suz12',
#  'Pcdhgb6',
#  'Cyp2s1',
#  'Btbd19',
#  'Echdc2',
#  'Ankrd52',
#  'Junb',
#  'Cep135',
#  'Hpdl',
#  'Tmem138',
#  'Gm38055',
#  'Ccdc159',
#  'Mgat4e',
#  'Ap5b1',
#  'Fas',
#  'Naaladl1',
#  'Tpt1-ps6',
#  'Lztfl1',
#  'Rpl15-ps6',
#  'Gmpr2',
#  'Casp2',
#  'Ccdc66',
#  'Mdm2',
#  'Gm43920',
#  'Acacb',
#  'Pcmtd2',
#  'Wdr83',
#  'Phactr1',
#  'Commd1b',
#  'Gm8643',
#  'Bsg',
#  'Slc10a7',
#  'Prorsd1',
#  'Atf4',
#  'Gm37899',
#  'Rnf166',
#  'Dpy19l4',
#  'Mtif2',
#  'Gm15903',
#  'Mpzl2',
#  'Fgf17',
#  'Rmnd5a',
#  'Tes',
#  'Gm48890',
#  'Ercc2',
#  'Trib1',
#  'Stag2',
#  'Spast',
#  'Tgfbi',
#  'Zfp709',
#  'Gadd45b',
#  'Adam8',
#  'Gm33989',
#  'Msh5',
#  'Tmem192',
#  'Trmt1',
#  'Hltf',
#  'Gfer',
#  'Erp44',
#  'Tmem88',
#  'Gm48602',
#  'Sh3kbp1',
#  'Traf3ip1',
#  'Satb1',
#  'Bcl2l14',
#  'Adamts7',
#  'Mpzl1',
#  'Galnt2l',
#  'Zrsr1',
#  'AI413582',
#  'Gm14048',
#  'Stx12',
#  'Gm10177',
#  'BC004004',
#  'Gskip',
#  'Gm47139',
#  'Zscan18',
#  'Depdc1a',
#  'Adm2',
#  'Rnf41',
#  'Wt1',
#  'Amfr',
#  'Maoa',
#  'Prkd3',
#  'Cand1',
#  'Gabarapl2',
#  'H4c14',
#  'Pak6',
#  'Spryd4',
#  'Tiparp',
#  'Stard13',
#  'Topors',
#  'Polr1c',
#  'Inpp5k',
#  'Slc9a7',
#  'Gm43815',
#  'Pard6g',
#  'Otulin',
#  'Zfyve19',
#  'Sf3b5',
#  'Rnf138',
#  'Lcmt2',
#  'Pgam5',
#  'Krt16',
#  'Lhx6',
#  'Ppl',
#  'A2m',
#  'Mak',
#  'Catip',
#  'Foxp4',
#  'Gm43790',
#  'Lztr1',
#  'Stk39',
#  'Rheb',
#  'Cyren',
#  'Zfp973',
#  'Foxp1',
#  'Zfp81',
#  'Nr2c1',
#  'Gm37677',
#  'Cdk2ap1',
#  'Etv6',
#  'AI504432',
#  'Nup188',
#  'Sptbn1',
#  'Memo1',
#  'Gm37678',
#  'Haus3',
#  'Gm10699',
#  'Babam2',
#  'Eif4a2',
#  'Gm43055',
#  'Gm43059',
#  'Gm43848',
#  'Mlst8',
#  'Gm5863',
#  'Phldb2',
#  '5330432J10Rik',
#  'Ankrd13a',
#  'Arhgap19',
#  'Glrx2',
#  'Gm49368',
#  'Tcn2',
#  'Psmd9',
#  'Sqstm1',
#  'Zfp990',
#  'Tada3',
#  'Snord94',
#  'Gm45717',
#  'Rnaseh1',
#  'mt-Nd2',
#  '1700086P04Rik',
#  'Tjp1',
#  'Ugt8a',
#  'Brd9',
#  'Cnpy4',
#  'Ralbp1',
#  'Rpl18-ps2',
#  'Lrch3',
#  'Gm43984',
#  'Tusc3',
#  'Cxcl14',
#  'Gm5805',
#  'Itfg2',
#  'Gm46344',
#  'Mettl27',
#  'Proser1',
#  'Cbx8',
#  'Tor2a',
#  'Zfp365',
#  'Lbh',
#  'Npas1',
#  'Gm19046',
#  'Il7',
#  'Cul5',
#  'Gm14393',
#  'Gm9260',
#  'Myo9a',
#  'Cdc26',
#  'Chmp2b',
#  'Gm17705',
#  'Nkx1-2',
#  'Etfb',
#  'G2e3',
#  'Limd1',
#  'Cdkn2aipnl',
#  'Srgap3',
#  'Lsm11',
#  'Gm37499',
#  'Zfp93',
#  'Rps27a-ps3',
#  'Plxdc2',
#  'Cog8',
#  'Gm43890',
#  'Tmsb10',
#  'Ext2',
#  'Gm5555',
#  'Pycr1',
#  'Khdrbs1',
#  'Frmd4b',
#  'Dact1',
#  'Necab2',
#  'Suox',
#  'Gm3081',
#  'Gm8116',
#  'Gm19972',
#  'Efr3b',
#  'Tmem121',
#  'Cnga3',
#  'Ralgapa1',
#  'Txndc17',
#  'Bri3bp',
#  'Tbc1d22a',
#  'Tax1bp3',
#  'Tafa5',
#  'Yy2',
#  'Tanc2',
#  'Ifi35',
#  'Tgif2',
#  'Tmem240',
#  'Kazn',
#  'Ssr1',
#  'Usf1',
#  'Gm8188',
#  'Rhoq',
#  'Aktip',
#  'Pcdhac1',
#  'Endod1',
#  'Lrrc56',
#  'Gm12922',
#  'Tor1a',
#  'Ddx19b',
#  'Klhl18',
#  'Abraxas1',
#  'Atraid',
#  'Pdcd11',
#  'Cox11',
#  'Zfp704',
#  'Neb',
#  'Zfp334',
#  'Nbea',
#  'Rpp40',
#  'Gm41760',
#  'Entpd6',
#  'Adrb2',
#  'H2ac24',
#  'Gm5464',
#  'Rnu12',
#  'Rab38',
#  'Vrk3',
#  'Grhpr',
#  'Camk2n1',
#  'C130036L24Rik',
#  'Tyms',
#  'Gm10856',
#  'Gm42462',
#  'St6galnac2',
#  'Ccdc34',
#  'H2-Eb1',
#  'Sh2d3c',
#  'Fto',
#  'Stt3b',
#  'Marveld1',
#  'Apobec2',
#  'Tmeff1',
#  'Gm49971',
#  'Gusb',
#  'Khdc4',
#  'Loxl3',
#  'Gtf2e2',
#  'Cpne7',
#  'Prss41',
#  'Dmap1',
#  'Zc3h14',
#  'Gm2531',
#  'Stard3',
#  'Metap2',
#  'Fkbp7',
#  'Traf4',
#  'Pabpc4',
#  'Hmgb1-ps6',
#  'Mpzl3',
#  'Iqce',
#  'Hrob',
#  'Dgkb',
#  '4833438C02Rik',
#  'Pltp',
#  'Mcee',
#  'Gm39469',
#  'Hyal1',
#  'Stc2',
#  '9930017N22Rik',
#  'Rlf',
#  'Gabbr1',
#  'Zfp125',
#  'Cdk9',
#  'Unk',
#  'Nfkb1',
#  'Rgp1',
#  'Miip',
#  'Gm14636',
#  'P2rx3',
#  'Ccdc122',
#  'Gk',
#  'Rbfaos',
#  'Stk17b',
#  'Copb1',
#  'Tlr5',
#  'Atg101',
#  'Scnm1',
#  'Nalcn',
#  'Dynlrb1',
#  'Itsn1',
#  'Zfp760',
#  'Klf13',
#  'Lemd2',
#  'Ufm1',
#  'Crkl',
#  'Zfp266',
#  'Ppib',
#  'Ldhb',
#  'Hacd2',
#  'Med14',
#  'Cgas',
#  'Smim12',
#  'Hecw1',
#  'Gm19238',
#  'Pabpc4l',
#  'Tgfbrap1',
#  'Gm9299',
#  'Prpf38b',
#  'Gm15226',
#  'Tshz3',
#  'Zcchc7',
#  'Gm49416',
#  'Gm49356',
#  'Kdm1b',
#  'Pik3r3',
#  'Fam171a2',
#  'Daam1',
#  'Gm9081',
#  'Gm14138',
#  '2410137M14Rik',
#  '1700025G04Rik',
#  'Tpt1-ps3',
#  'Smad1',
#  'Nectin4',
#  'Coro6',
#  'Mknk1',
#  'Gm4556',
#  'Rbpj-ps3',
#  'Dhx15',
#  'Prdm1',
#  'Dppa5a',
#  'Capza2',
#  'Gm9522',
#  'Ncoa7',
#  'Gm12168',
#  'Zfp951',
#  '2410018L13Rik',
#  'A530064N14Rik',
#  'Sp8',
#  'Gm6443',
#  'Glt1d1',
#  'Tmem231',
#  'Hspa8',
#  '4930522L14Rik',
#  'Glrx3',
#  'Des',
#  'Gm4824',
#  'Aif1l',
#  'Ccdc88b',
#  'Slc35e4',
#  'Dscc1',
#  'Zbtb42',
#  'Ankrd42',
#  'Chpf',
#  'Heatr6',
#  'Usf2-ps1',
#  'Slc43a1',
#  'Mrps33',
#  'Tbpl1',
#  'Cpsf2',
#  'Nt5c3',
#  'Jund',
#  'Gm47761',
#  'Tcfl5',
#  'Nadk2',
#  'Gm37598',
#  'Frg1',
#  'Fam71e1',
#  'Calcoco1',
#  'Dnaaf5',
#  '2310058D17Rik',
#  'Mrpl12',
#  'Csf2ra',
#  'Tnfrsf21',
#  'Fndc3b',
#  'Ube2z',
#  'Olfr77',
#  'Polb',
#  'Naa80',
#  'Depdc7',
#  'Mtf2',
#  'Gm42998',
#  '2700049A03Rik',
#  'Nars',
#  'Aspg',
#  'Elf4',
#  'Gm44913',
#  'Gpi1',
#  'Zswim7',
#  'Msi1',
#  'Pou5f1',
#  'Gm29724',
#  'Elmo2',
#  'Plce1',
#  'Sf3b1',
#  'Marchf7',
#  'Gm50431',
#  'Slc35e3',
#  'Pogk',
#  'Bckdk',
#  'Gm43343',
#  'Tnni1',
#  'Zfp711',
#  'Abcf2',
#  'Gm29666',
#  'Nlgn3',
#  'Ezh2',
#  'Utf1',
#  'Parl',
#  'Jade1',
#  'Usp8',
#  '6030442K20Rik',
#  'Bahcc1',
#  'Slc16a14',
#  'Tpcn1',
#  'Syt14',
#  'Tpcn2',
#  'Edar',
#  'Astn1',
#  'Aida',
#  'Asap2',
#  'Acbd3',
#  'Gsn',
#  'Ubn2',
#  'Gm26965',
#  'Apc2',
#  'Zfp618',
#  'Flad1',
#  'Chst1',
#  'Foxd2os',
#  '9630014M24Rik',
#  'Cnksr2',
#  'Gramd1c',
#  'Gm20163',
#  'Gm14148',
#  'Plcb2',
#  'Gm43462',
#  'Castor2',
#  'Grb14',
#  'Commd2',
#  'Gm49358',
#  'Pkm',
#  'Gm10167',
#  'Qpct',
#  'Lrguk',
#  'Dsc2',
#  'Arhgap30',
#  'ENSMUSG00000119662',
#  'Gm31166',
#  'Kdm4c',
#  'Ppp1r2',
#  'Lonp1',
#  'Gtf3c2',
#  'Tor1b',
#  'Art5',
#  'Syt7',
#  'Kank3',
#  'Gm21814',
#  'Cntnap2',
#  'Bnip2',
#  'Klhl25',
#  'Slc38a4',
#  'Tbc1d15',
#  'Luc7l2',
#  'Gm3317',
#  'Was',
#  'Gm10933',
#  'Bphl',
#  'Mok',
#  'Prmt6',
#  'Atxn2',
#  'Polr3a',
#  'Glp1r',
#  'Snx11',
#  'Plekhm3',
#  'Usp44',
#  'Znrf3',
#  'Cth',
#  'Wnk3',
#  'Ecel1',
#  'Klhl8',
#  'Pelo',
#  'Zfp189',
#  'Wnt7b',
#  'C1d',
#  'Slc25a42',
#  'Cd59b',
#  'Rnf208',
#  'Tmem104',
#  'Dsg2',
#  'Xkr8',
#  'Enpp1',
#  'Tpm2',
#  'Rps6',
#  'Gorab',
#  'Atp6v1d',
#  'Slc9b1',
#  'Gramd1b',
#  'Celf5',
#  'Mfng',
#  'Gm13642',
#  'Gnaz',
#  'Gm42989',
#  'Nemp2',
#  'Gm8399',
#  'Pcca',
#  'Rnf130',
#  'Ss18',
#  '4833420G17Rik',
#  'Klf3',
#  'Ykt6',
#  'Gm47624',
#  'Tspyl1',
#  'Dnajc30',
#  'mt-Atp8',
#  'Mrps23',
#  'Gm42819',
#  'Dna2',
#  'Ddx4',
#  'Ascl2',
#  'mt-Rnr2',
#  'Psenen',
#  'Pou4f2',
#  'Mogs',
#  'Lyrm9',
#  'Wdr7',
#  'Tet1',
#  'Ccdc8',
#  'Gbx2',
#  'Zfp36l2',
#  'Gm18736',
#  'Ptrh1',
#  'Gm13261',
#  'Fbxo11',
#  'Carmil3',
#  'Gm47398',
#  'Tmem39b',
#  'Cd109',
#  'Gabre',
#  'Gm16233',
#  'Ccdc150',
#  'Zfp13',
#  'Gm42515',
#  'Kif27',
#  'Snora57',
#  'Fgf4',
#  'Mpv17',
#  'Lrp1',
#  'Rnf225',
#  'Gm6166',
#  'Grina',
#  'Gm48643',
#  'Gm49839',
#  'Abhd8',
#  'Atp5pb-ps',
#  'Exo1',
#  'Rcbtb2',
#  'Grip2',
#  'Tubb4a',
#  'Sgo2a',
#  'Ap2b1',
#  'Iqcc',
#  'Vamp3',
#  'Exoc3l2',
#  'Setd5',
#  'Rab3a',
#  'Dph1',
#  'Pgp',
#  'Phtf1os',
#  'Rhno1',
#  'Ccdc174',
#  'Iscu',
#  'Itgav',
#  'AA914427',
#  'Znrf2',
#  '4632404H12Rik',
#  'Tesk1',
#  'Etfa',
#  'Zfand2b',
#  'Scn5a',
#  'Mir1193',
#  'Wdr55',
#  'Nudt7',
#  'Fbxo22',
#  'Mageb16',
#  'Plekha1',
#  'Myh10',
#  'N6amt1',
#  'Pla2r1',
#  'Rtca',
#  'Naif1',
#  'R3hdm1',
#  'Cpt1c',
#  'Phka2',
#  'Cd3e',
#  'Gm2308',
#  'Mcm4',
#  'Wdr82',
#  '2500002B13Rik',
#  'Vps16',
#  'Nek4',
#  'Gm24105',
#  '9430031K09Rik',
#  'Gm13146',
#  'Ube2n',
#  'Edem1',
#  'Gm45293',
#  'Mcm9',
#  'Rbm38',
#  'Nectin1',
#  'Wdfy2',
#  'Uqcrc1',
#  'Dhx30',
#  'Ltv1',
#  'Mnt',
#  'Phox2a',
#  'Plscr1',
#  'Rxylt1',
#  'Zfp335',
#  'Cfap300',
#  'Phyh',
#  'Abhd10',
#  'H2bc9',
#  'Eif3l',
#  'Ap4s1',
#  'Irx5',
#  'Tyro3',
#  'Pcbp3',
#  'Tsc1',
#  'Odf2l',
#  'Nr6a1',
#  'Magef1',
#  'Lratd2',
#  'Slc1a5',
#  'Fam193a',
#  'Fzd5',
#  'Plxdc1',
#  'Rbm33',
#  'Serpinb6a',
#  'Anks3',
#  'Nfyc-ps',
#  'Gm7424',
#  'Ifitm7',
#  'Gm14277',
#  'Furin',
#  'Lmo7',
#  'Gm16286',
#  'Stom',
#  'H2ac1',
#  'Sprtn',
#  'Zscan20',
#  'Zfp277',
#  'Mapk12',
#  'Rbis',
#  'Alkbh5',
#  'Ap4b1',
#  'Boc',
#  'Mfn2',
#  'Sec23ip',
#  'Bag4',
#  'Gm18860',
#  'Ipo13',
#  'Ank1',
#  'Nlrc4',
#  'Sfrp1',
#  'Cd164',
#  'Mif-ps6',
#  '1700040D17Rik',
#  'Purg',
#  'Myo1a',
#  'Lpcat1',
#  'Taf1a',
#  '2210016L21Rik',
#  'Gcsh',
#  'Rab10',
#  'Tle1',
#  'Gga1',
#  'Psma4',
#  'Plcd4',
#  'Herc2',
#  'Olfr889',
#  'Tubb4b',
#  'Pde12',
#  'Spred3',
#  'Xk',
#  'Dsp',
#  'Dram2',
#  'Gm50478',
#  'Gm44901',
#  'Tsc22d3',
#  'Stip1',
#  '2610318N02Rik',
#  'Pim2',
#  'Hsdl1',
#  'Sec24c',
#  '9430038I01Rik',
#  'Ctbp1',
#  '6820402A03Rik',
#  'Map2k1',
#  'Gm45447',
#  'Fam83e',
#  'Fam178b',
#  'Gm42067',
#  '9530068E07Rik',
#  'Foxh1',
#  'C130083A15Rik',
#  'Emsy',
#  'Trim11',
#  'Gmppa',
#  'Trmt10b',
#  'Rasa1',
#  'U2af1l4',
#  'Plekhd1',
#  'Alcam',
#  'Spsb2',
#  'Vars2',
#  'Gm11837',
#  'Nktr',
#  '2700046G09Rik',
#  '2700038G22Rik',
#  'Reep6',
#  'Pign',
#  'Pcyox1l',
#  'Psma6',
#  'Myo7a',
#  'Srd5a1',
#  'Gm10282',
#  'Csmd2',
#  'Ndufb11b',
#  'Arid3a',
#  'Aars2',
#  'Ahsg',
#  'Orc2',
#  'Ddx3x',
#  'Comt',
#  'Gm43305',
#  'Rbms1',
#  'Pigc',
#  'Rnf10',
#  'Mccc2',
#  'Rpl19-ps6',
#  'Emp3',
#  'Ypel1',
#  'Itm2b',
#  '2310001H17Rik',
#  '1700028E10Rik',
#  'Mfsd13a',
#  'Eif4e2',
#  'Smim17',
#  'Gm13166',
#  'Daglb',
#  'Ttc14',
#  'Rufy2',
#  'Klhl13',
#  'Dock5',
#  '2310009B15Rik',
#  'Olfr1388',
#  'Pcdhgc5',
#  'Morf4l1',
#  'Ociad2',
#  'BB218582',
#  'Fnip1',
#  'Tubd1',
#  'Slc16a6',
#  'Gm12335',
#  'Tgs1',
#  'Arhgef25',
#  'Clba1',
#  'Zfp638',
#  'Mmp15',
#  'Emp2',
#  'Dusp22',
#  'Gm45809',
#  'Aste1',
#  'Dmac2l',
#  '6720464F23Rik',
#  'Gm40989',
#  'Atp6v1c1',
#  ...}

# %%
# read an excel file
TE = pd.read_excel('Data/Ingolia_riboseq/1-s2.0-S0092867411011925-mmc1.xls', sheet_name='Table S1C')
TE = TE[(TE['Gene'].isin(expressed_gene_names_set))]
TE
# Out:
#           UCSC ID  ribosome    mRNA   TE ratio  log2 TE     Gene  \
# 5      uc008lvc.1       1.0    58.5   0.013832    -6.18  Pla2g4b
# 8      uc009fwv.1       9.0   241.0   0.030218    -5.05  Map3k10
# 9      uc009gvf.1      53.0  1163.0   0.036876    -4.76     Ftl1
# 10     uc009flb.1       8.0   131.0   0.049416    -4.34     Gpr4
# 12     uc008ujb.1      17.0   223.0   0.061687    -4.02  B4galt2
# ...           ...       ...     ...        ...      ...      ...
# 10215  uc007yue.1     860.5    87.0   8.003468     3.00      Lpp
# 10216  uc007kzn.1    2751.0   239.0   9.314066     3.22   Col1a1
# 10217  uc008lrq.1    7244.5   575.5  10.186141     3.35    Thbs1
# 10218  uc009avm.1    1418.0   107.0  10.723562     3.42   Col1a2
# 10219  uc007uko.1    1803.0   106.0  13.763740     3.78   Dpysl2
#
#                                           Description
# 5                         phospholipase A2, group IVB
# 8      mitogen activated protein kinase kinase kinase
# 9                              ferritin light chain 1
# 10                       G protein-coupled receptor 4
# 12                       UDP-Gal:betaGlcNAc beta 1,4-
# ...                                               ...
# 10215   LIM domain containing preferred translocation
# 10216                    procollagen, type I, alpha 1
# 10217                                thrombospondin 1
# 10218                    procollagen, type I, alpha 2
# 10219                      dihydropyrimidinase-like 2
#
# [8088 rows x 7 columns]

# %%
masterfile = pd.read_csv('/ceph/hpc/home/novljanj/data_storage/projects/smOOPS_paper/Data/masterfile/all_smOOPS_and_controls_V2.tsv', sep='\t')
masterfile["all_smoops"] = masterfile["smoops_naive"] | masterfile["smoops_epi"] | masterfile["smoops_diff"]
masterfile["all_smoops"].value_counts()
masterfile
# Out:
#        chr      start        end                gene_id     feature strand  \
# 0     chr1    3284704    3741721   ENSMUSG00000051951.6  transcript      -
# 1     chr1    3435953    3438772   ENSMUSG00000103377.2  transcript      -
# 2     chr1    3445778    3448011   ENSMUSG00000104017.2  transcript      -
# 3     chr1    3535199    3537508   ENSMUSG00000103025.2  transcript      -
# 4     chr1    3582673    3584730   ENSMUSG00000103201.2  transcript      -
# ...    ...        ...        ...                    ...         ...    ...
# 3055  chrX  160616291  160942726  ENSMUSG00000059493.14  transcript      -
# 3056  chrX  165173028  165223700   ENSMUSG00000040586.9  transcript      -
# 3057  chrX  168094525  168103276  ENSMUSG00000031352.11  transcript      -
# 3058  chrY    1260770    1286629  ENSMUSG00000069045.12  transcript      -
# 3059  chrM       1093       2675   ENSMUSG00000064339.1  transcript      +
#
#      gene_name          transcript_id  feature_length  smoops_naive  \
# 0         Xkr4   ENSMUST00000070533.5          457017         False
# 1      Gm37180   ENSMUST00000195335.2            2819         False
# 2      Gm37363   ENSMUST00000192336.2            2233         False
# 3      Gm37686   ENSMUST00000194099.2            2309         False
# 4      Gm37329   ENSMUST00000192973.2            2057         False
# ...        ...                    ...             ...           ...
# 3055       Nhs  ENSMUST00000087085.10          326435         False
# 3056      Ofd1   ENSMUST00000049501.9           50672         False
# 3057      Hccs   ENSMUST00000033717.9            8751         False
# 3058     Ddx3y  ENSMUST00000091190.12           25859         False
# 3059   mt-Rnr2   ENSMUST00000082390.1            1582         False
#
#       smoops_epi  smoops_diff  control_common  semi_diff_mean_tpm  \
# 0           True         True           False            3.872970
# 1           True         True           False            0.521827
# 2          False         True           False            0.485116
# 3          False         True           False            0.627143
# 4          False         True           False            1.040409
# ...          ...          ...             ...                 ...
# 3055        True         True           False            0.707368
# 3056        True         True           False            2.596442
# 3057       False        False            True            8.779636
# 3058        True         True           False           12.061610
# 3059       False         True           False          277.844274
#
#       semi_epiSC_mean_tpm  semi_naive_mean_tpm  semi_diff_mean_count  \
# 0                2.324972             0.014051            194.333000
# 1                0.301747             0.012481             22.666667
# 2                0.206451             0.000000             14.333333
# 3                0.321620             0.000000             18.000000
# 4                0.393665             0.000000             30.333333
# ...                   ...                  ...                   ...
# 3055             0.917609             0.077997             91.000000
# 3056             2.308879             1.399653            165.333333
# 3057             9.323919             9.318443            270.333333
# 3058             9.830595             1.813766            633.994667
# 3059            47.457855            38.049362           5153.666667
#
#       semi_epiSC_mean_count  semi_naive_mean_count  all_smoops
# 0                235.666667               0.666667        True
# 1                 26.666667               0.333333        True
# 2                 15.666667               0.000000        True
# 3                 24.666667               0.000000        True
# 4                 25.333333               0.000000        True
# ...                     ...                    ...         ...
# 3055             245.000000               6.000000        True
# 3056             326.725000              86.666667        True
# 3057             630.333333             302.000333       False
# 3058            1141.029333              96.344667        True
# 3059            2071.315667             742.666667        True
#
# [3060 rows x 20 columns]

# %%
clusters = pd.read_csv('Results/machine_learning_results/cluster_assignment_file/sequence:global_iclip:paris_intramol:postar3_joined_clusters.tsv', sep='\t')
clusters["Cluster"].value_counts()
# Out:
# Cluster
# 0    328
# 1    119
# Name: count, dtype: int64

# %%
merged = pd.merge(TE, masterfile, right_on='gene_name', left_on='Gene', how='left')   
merged = pd.merge(merged, clusters, right_on='transcript_id', left_on='transcript_id', how='left')

merged["gene_id"] = merged["gene_id"].str.split('.').str[0]
merged['all_smoops'] = merged['all_smoops'].fillna(False)
merged["non-smOOPs"] = ~merged["gene_name"].isin(set((masterfile[masterfile["smoops_naive"] == True]["gene_name"])))

merged["in_cluster_0_and_smoops_naive"] = (merged["Cluster"] == 0) & (merged["smoops_naive"])
merged["in_cluster_1_and_smoops_naive"] = (merged["Cluster"] == 1) & (merged["smoops_naive"])
# Out:
# /tmp/ipykernel_970271/1896034443.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged['all_smoops'] = merged['all_smoops'].fillna(False)

# %%
def plot_boxplot(df, value_column, control_column, compare_boolean_columns):

    conditions = [control_column] + compare_boolean_columns
    filtered_data = pd.DataFrame({
        condition: df[df[condition] == True][value_column] for condition in conditions
    })

    melted_data = filtered_data.melt(var_name='Condition', value_name=value_column)
    
    comparisons = [(control_column, condition) for condition in compare_boolean_columns]
    results = []
    for test_a, test_b in comparisons:
        test_a_data = filtered_data[test_a].dropna().to_list()
        test_b_data = filtered_data[test_b].dropna().to_list()
        print(f'{test_a}: {len(test_a_data)} data points, mean = {np.mean(test_a_data):.2f}')
        print(f'{test_b}: {len(test_b_data)} data points, mean = {np.mean(test_b_data):.2f}')
        stat, p_val = ttest_ind(test_a_data, test_b_data, equal_var=False)
        #stat, p_val = mannwhitneyu(test_a_data, test_b_data)
        results.append((test_a, test_b, p_val))
        print(f'{test_a} vs {test_b}: p-value = {p_val:.3f}')
        
    hex_palette = {control_column: '#bdcae2'}
    hex_palette.update({name: sns.color_palette('Set3')[idx] for idx, name in enumerate(compare_boolean_columns)})
    white_palette = {key: '#FFFFFF' for key in hex_palette.keys()}
    
    plt.figure(figsize=(len(compare_boolean_columns) * 0.5 + 2, 6))

    sns.violinplot(x='Condition', y=value_column, data=melted_data, palette=white_palette, inner=None, gap=0.3, zorder=0)

    ax = sns.boxplot(x='Condition', y=value_column, data=melted_data, palette=hex_palette, showfliers=False, width=0.15, whis=0, zorder=2)    
    
    y_max = melted_data[value_column].max() + 2 
    y_step = y_max / 11 

    for idx, (test_a, test_b, p_val) in enumerate(results):
        x1, x2 = conditions.index(test_a), conditions.index(test_b)
        y, h = y_max + idx * y_step, y_step / 4
        ax.plot([x1, x1, x2, x2], [y, y + h, y + h, y], lw=1.5, c='black')
        significance = "***" if p_val < 0.001 else "**" if p_val < 0.01 else "*" if p_val < 0.05 else "ns"
        ax.text((x1 + x2) * 0.5, y + h, significance, ha='center', va='bottom', color='black')
    
    plt.title(f'smOOPS {value_column} by Stage', fontsize=16)
    plt.ylabel(f'{value_column}', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)

    ax.set_xticklabels(conditions)

    legend_elements = [mpatches.Patch(color=hex_palette[name], label=name.replace('_', ' ').capitalize()) for name in hex_palette]
    plt.legend(handles=legend_elements, loc='upper right', bbox_to_anchor=(1.7, 1), frameon=False)

    sns.despine()
    plt.show()
    
plot_boxplot(merged, value_column='log2 TE', control_column = "non-smOOPs", compare_boolean_columns = ["in_cluster_0_and_smoops_naive", "in_cluster_1_and_smoops_naive"])
# Out:
# /tmp/ipykernel_970271/3393720708.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y=value_column, data=melted_data, palette=white_palette, inner=None, gap=0.3, zorder=0)
# non-smOOPs: 7804 data points, mean = 0.37
# in_cluster_0_and_smoops_naive: 255 data points, mean = 0.46
# non-smOOPs vs in_cluster_0_and_smoops_naive: p-value = 0.099
# non-smOOPs: 7804 data points, mean = 0.37
# in_cluster_1_and_smoops_naive: 28 data points, mean = 0.38
# non-smOOPs vs in_cluster_1_and_smoops_naive: p-value = 0.940
# /tmp/ipykernel_970271/3393720708.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='Condition', y=value_column, data=melted_data, palette=hex_palette, showfliers=False, width=0.15, whis=0, zorder=2)
# /tmp/ipykernel_970271/3393720708.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(conditions)
