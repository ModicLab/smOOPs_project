# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
plt.rcParams["svg.fonttype"] = "none"  # Ensures the text is not converted to paths
import matplotlib.patches as mpatches
from scipy.stats import ttest_ind, mannwhitneyu

# %%
semi_naive_deseq = pd.read_csv('Data/deseq2_results_tables/semi_naive_vs_control_naive_deseq.tsv', sep="\t")

expressed_genes_set = set(semi_naive_deseq['gene_id'])
print("length of expressed_genes_set: ", len(expressed_genes_set))

transcript_data = []

with open('genomes/genome_m39/gencode.vM27.chr_patch_hapl_scaff.annotation.gtf', 'r') as gtf_file:
    for line in gtf_file:
        if line.startswith('#'):
            continue

        columns = line.strip().split('\t')
        attributes = columns[8]

        if 'transcript_id' in attributes:
            gene_name = [field for field in attributes.split(';') if 'gene_name' in field][0]
            gene_name = gene_name.split('"')[1]
            gene_id = [field for field in attributes.split(';') if 'gene_id' in field][0]
            gene_id = gene_id.split('"')[1]
            transcript_id = [field for field in attributes.split(';') if 'transcript_id' in field][0]
            transcript_id = transcript_id.split('"')[1]
            gene_type = [field for field in attributes.split(';') if 'gene_type' in field][0]
            gene_type = gene_type.split('"')[1]

            transcript_data.append(columns[:7] + [gene_id] + [gene_name] + [transcript_id] + [gene_type])

column_names = ['seqname', 'source', 'feature', 'start', 'end', 'score', "strand", "gene_id", "gene_name", 'transcript_id', 'gene_type']

annotation = pd.DataFrame(transcript_data, columns=column_names)
annotation['start'] = annotation['start'].astype(int) - 1
annotation = annotation[annotation['feature'] == 'transcript']

gene_id_to_name = dict(zip(annotation['gene_id'], annotation['gene_name']))

expressed_gene_names_set = set([gene_id_to_name[gene_id] for gene_id in expressed_genes_set])
expressed_gene_names_set
# Out:
# length of expressed_genes_set:  16484
# {'Ccdc97',
#  'Hsd17b12',
#  'Erf',
#  'Gm38125',
#  'Smg1',
#  'Plxnd1',
#  'Gm16196',
#  'Enox1',
#  'Diaph1',
#  'Gm12989',
#  'Smc1a',
#  'Rbm19',
#  'Lpar6',
#  'Slc30a5',
#  'Hsdl1',
#  'Dhcr24',
#  'Tesmin',
#  'Hmox1',
#  'Gm5487',
#  'Ap1s1',
#  'Plekha5',
#  'Ythdf1',
#  'Pcbd2',
#  'Usp1',
#  'A330023F24Rik',
#  'Asphd2',
#  '1700007L15Rik',
#  '2210412B16Rik',
#  'Pla2g4e',
#  'Tgm1',
#  'Fmn1',
#  'Acoxl',
#  'Gm9083',
#  'Nrg1',
#  'Tdrd3',
#  'Map2k3',
#  'Ccdc106',
#  'Mob1a',
#  'Wdpcp',
#  'Vsig10l',
#  'Bmi1',
#  'Gm14419',
#  'Tspan33',
#  'Klhl23',
#  'Mob3c',
#  'H1f4',
#  'Spcs2',
#  'Trnt1',
#  'Gm13642',
#  'Gga2',
#  'Fam177a',
#  'Bloc1s4',
#  'Pim1',
#  'Plrg1',
#  'Kcnk2',
#  'Isca2',
#  'Ssr4',
#  'Gm45309',
#  'Git1',
#  'Mindy4',
#  'Nell2',
#  'Rpl6l',
#  'Ogdhl',
#  'Ptrh2',
#  'Inpp5a',
#  'Dnajc14',
#  'Pde4dip',
#  'Donson',
#  'Kynu',
#  'Mageb3',
#  'Kcnn1',
#  'Apol6',
#  'Exog',
#  'Arvcf',
#  'Zc3h7a',
#  'Ppfibp2',
#  'Rps6ka2',
#  'Pak2',
#  'Gm37436',
#  'Efcab1',
#  'Hs2st1',
#  'Gm8730',
#  'Gm37033',
#  'Elmo1',
#  'Gm4609',
#  'Cwc22',
#  'Frs2',
#  'Alg8',
#  'Mettl5',
#  'Phlda2',
#  'Fam171a1',
#  '2610318N02Rik',
#  'Rabepk',
#  'Cdc5l',
#  'Ciapin1',
#  'Blmh',
#  'Tsen34',
#  'Creg2',
#  'Heca',
#  'Rfk',
#  'Dcps',
#  'Sez6',
#  'Catsperd',
#  'Tcp11x2',
#  'Gm49356',
#  'Aebp2',
#  '3830406C13Rik',
#  'Cdc6',
#  'Adamts8',
#  '2810030D12Rik',
#  'mt-Nd5',
#  'Crtc1',
#  'Tgif1',
#  'Pgd',
#  'Psmg2',
#  'Nsd3',
#  'Gm9826',
#  'Ankib1',
#  'Gm26397',
#  'Gm9794',
#  'Elk4',
#  'Clip3',
#  'Gm45809',
#  'Ddx58',
#  'Cdkn2c',
#  'Trim12a',
#  'Ube2n',
#  'Ncbp1',
#  'Tlnrd1',
#  'Gm36936',
#  'Trappc6a',
#  'Trip4',
#  'Lrfn3',
#  'Tysnd1',
#  'Atp13a1',
#  'Litaf',
#  'Gm20632',
#  'Thap12',
#  'Tppp3',
#  'Ccdc59',
#  'Mink1',
#  'Gpatch1',
#  'Kmt5b',
#  'Tpi-rs11',
#  'Myo19',
#  'Slco2a1',
#  'Wfdc2',
#  'Eif3i',
#  'Bcs1l',
#  'Zfp109',
#  'Rps8-ps1',
#  'Zmat2',
#  'Csrnp3',
#  'Nsd1',
#  'Sesn3',
#  'Gm12917',
#  'Uba52',
#  'Gm48412',
#  'Wwp1',
#  'Zfp951',
#  'Nr4a1',
#  'Psmc3',
#  'Ntan1',
#  'Mesd',
#  'Pqbp1',
#  'Dhx16',
#  'Ablim2',
#  'Stimate',
#  'Pde9a',
#  'Tmem17',
#  'Omp',
#  'Mmp25',
#  'Selenoh',
#  'Gm11635',
#  'Rp2',
#  '9230116N13Rik',
#  'Gstp1',
#  '1700123M08Rik',
#  'Iqce',
#  'Insr',
#  'Afmid',
#  '1700007K13Rik',
#  'Gm38366',
#  'Yeats2',
#  'Mpc1-ps',
#  'Slc25a19',
#  'Utrn',
#  'Armcx4',
#  'Anapc2',
#  'Cdhr1',
#  'Mettl25',
#  'Nsmce4a',
#  'Gm38375',
#  'Npm1',
#  'Lrp2bp',
#  'Nrep',
#  'Rrp9',
#  'Pdgfb',
#  'Castor2',
#  'Thap3',
#  'Gm17203',
#  '4921534A09Rik',
#  'Slc45a1',
#  'C330011M18Rik',
#  'Gm37212',
#  'Herc4',
#  'Raly',
#  'Rab36',
#  '1500002C15Rik',
#  'Fam104a',
#  'Swt1',
#  'Sh3rf3',
#  'Ube2g2',
#  'Gtf2ird1',
#  'Vcpip1',
#  'Bola3',
#  'Odad4',
#  'B020010K11Rik',
#  'Zfp318',
#  'Gm4961',
#  'Gm15365',
#  'Commd9',
#  'Gm5869',
#  '4931406C07Rik',
#  'Rpl23a-ps3',
#  'Rap2b',
#  'Fam169a',
#  'Zc2hc1c',
#  'Ccdc47',
#  'Dap',
#  'Cyp2s1',
#  '4732440D04Rik',
#  'Mrpl28',
#  'Cenpx',
#  'Capn5',
#  'Sgtb',
#  'Arrdc2',
#  'Gm48602',
#  'Sirt2',
#  'Ttc41',
#  '5330411J11Rik',
#  'Gm50478',
#  'Srsf2',
#  'Epb41l4b',
#  'Pithd1',
#  '2610001J05Rik',
#  'Ass1',
#  'Fgf5',
#  'Gm14387',
#  'Col1a2',
#  'Nme4',
#  'Cdon',
#  'Gm38148',
#  'Cdk8',
#  'Gale',
#  'Ahcy',
#  'Myb',
#  'Gm48713',
#  'Tmub1',
#  'Nudt9',
#  'Slc39a14',
#  'Chpt1',
#  'Tmem86a',
#  'Gm2436',
#  'Ostc',
#  'Tnfrsf11a',
#  'Slc25a46',
#  'Gm8292',
#  'Sbds',
#  '2310022A10Rik',
#  'Orc3',
#  'D430020J02Rik',
#  'Med12',
#  'Rtcb',
#  'Vamp1',
#  'Cyp4f16',
#  'Gabra5',
#  'Gm25432',
#  'Ak2',
#  'Zfp324',
#  'Lrfn4',
#  'Ubxn2b',
#  'Cep19',
#  'Srsf10',
#  'Rpl36-ps3',
#  'Nit1',
#  'Armc9',
#  'Pkd1l1',
#  'Gm16310',
#  'Gm10134',
#  'Dennd4c',
#  'ENSMUSG00002076937',
#  'Ccser2',
#  'Rap1gap',
#  'Gm37879',
#  'Zfp934',
#  '2700078F05Rik',
#  'Stard7',
#  'Polr2c',
#  'Gm12918',
#  'Wipi2',
#  'Slc1a4',
#  'Gm11496',
#  'Klf16',
#  'Eprs',
#  'Pik3r1',
#  'Map4k5',
#  'Retsat',
#  'Pid1',
#  'Tor2a',
#  'Gm4221',
#  'Foxr1',
#  'Foxm1',
#  'Tubgcp6',
#  'Gm6445',
#  'Fgf17',
#  'Slc51a',
#  'Serinc3',
#  'Xrn2',
#  'Hipk3',
#  'Niban2',
#  'Atp5e',
#  'Gm49416',
#  'Polr2g',
#  'Ttc19',
#  'Pag1',
#  'Gm14117',
#  'St3gal5',
#  'Zxdc',
#  'Baiap2l1',
#  'Gm9887',
#  'Pgam1',
#  'Zyg11a',
#  'Mob3b',
#  'Tmem144',
#  'Tmem220',
#  'Hey1',
#  'Gm3739',
#  'Rnf121',
#  'Gm43359',
#  'Stag1',
#  'Rock1',
#  'Nfx1',
#  'Cbl',
#  'Cenpq',
#  'Rev3l',
#  'Rskr',
#  'Gm43807',
#  'Sf3a2',
#  '2610011E03Rik',
#  'Gm25813',
#  'Zfp36l2',
#  'Rel',
#  'Mrpl34',
#  'Tnfsf13',
#  'Obsl1',
#  'Hapln4',
#  'Abcb7',
#  'Gm6869',
#  'Tnfrsf13b',
#  'Ahnak2',
#  'Rab15',
#  'Gm49058',
#  'Gm10062',
#  'E130018N17Rik',
#  'Cfap298',
#  'Rsu1',
#  'Dstyk',
#  'Rpl28-ps1',
#  'Kcnj3',
#  'Rbks',
#  'Neat1',
#  'Wnt3',
#  'Ankrd46',
#  'Gm49260',
#  'Klhl22',
#  'Gm42717',
#  'Ghdc',
#  'Tmem50a',
#  'ENSMUSG00000119662',
#  'Gm17018',
#  'Gm15599',
#  'Sptlc1',
#  'B230217C12Rik',
#  'Zwint',
#  'Aph1a',
#  'Rnf146',
#  'Cacna2d1',
#  'Ephx1',
#  'Tmem164',
#  'Commd1b',
#  'Saal1',
#  'Rnaset2b',
#  'Shfl',
#  'Gm527',
#  'Kis2',
#  'Nr2f6',
#  'Gm47615',
#  'Calm1',
#  'Luc7l2',
#  'Cs',
#  '2400006E01Rik',
#  'Gm43182',
#  'Tspan1',
#  'Yipf1',
#  'Riox1',
#  'Cyb5a',
#  'Parvg',
#  'Cct6b',
#  'Zfp292',
#  'Hypk',
#  'Trpv4',
#  'Asah2',
#  'Plat',
#  'Zfp768',
#  'Tmtc1',
#  'Hat1',
#  'Wbp4',
#  'Srp9',
#  'Gm20555',
#  'Tex30',
#  'Obscn',
#  'Zfp975',
#  'Arhgap23',
#  'Dnah12',
#  'Gm11532',
#  'Atp13a2',
#  'Krba1',
#  'Pigv',
#  'Nrf1',
#  'Gm8976',
#  '1110025M09Rik',
#  'Sco1',
#  'Urod',
#  'Ankrd13d',
#  'Sema3f',
#  'Gm16046',
#  'Amt',
#  'Gjb2',
#  'Gm48069',
#  'Arsk',
#  'Mical1',
#  'Zbtb49',
#  'BC034090',
#  'Ppp1r15b',
#  'Gata3',
#  'Atp6v1d',
#  'Itm2c',
#  'Gm16286',
#  'Dennd11',
#  'Mcoln3',
#  'Pym1',
#  'Phactr4',
#  'Gm2a',
#  'Dtd1',
#  'Zfp862-ps',
#  'Foxred1',
#  'Tmem94',
#  'Tmem189',
#  'Zfp783',
#  'Rer1',
#  'P2rx3',
#  'Zdhhc2',
#  'Gm43322',
#  'Sfmbt2',
#  'Epb41l3',
#  'Xpo6',
#  'Pibf1',
#  'Tamalin',
#  'Myg1',
#  'Extl1',
#  'Gm37968',
#  'Nsrp1',
#  'Gm45592',
#  'Tex14',
#  'Gm31645',
#  'Swsap1',
#  'Rpl18-ps2',
#  'Rmdn1',
#  'Zc3hav1l',
#  'Gng2',
#  'Slc27a3',
#  'Gm28323',
#  'Tmx3',
#  'Ascl2',
#  'Eea1',
#  'Garre1',
#  'Ddx56',
#  'Pald1',
#  '5031425E22Rik',
#  'Cass4',
#  'Pitpnc1',
#  'Rfx3',
#  'Gm47624',
#  'Pip5k1a',
#  'Stard8',
#  'Gdap1',
#  '2700049A03Rik',
#  'Adamts14',
#  'Btg1',
#  'Qrsl1',
#  '4930447C04Rik',
#  'Dennd4a',
#  'Aspa',
#  'Rny1',
#  'Cebpg',
#  'Gm25848',
#  '5430416N02Rik',
#  'Cx3cl1',
#  'Dnai2',
#  'Syf2',
#  'Itpr2',
#  'Rpl7l1',
#  'Gm45640',
#  'Ndrg4',
#  'P3h1',
#  'Aqr',
#  'Gm45220',
#  'Plcb3',
#  'Trim8',
#  'Pi4kb',
#  'Gm29164',
#  'Msh3',
#  'Mpzl1',
#  'Pigu',
#  'Tsc22d3',
#  'Nbr1',
#  'Gpx7',
#  'Clasrp',
#  'Xxylt1',
#  'Maskbp3',
#  'Psma5',
#  'Sel1l3',
#  'Fermt2',
#  'Nt5c3',
#  'Fam222a',
#  'Twist1',
#  'Atp1a2',
#  'Gm14165',
#  'Eif4ebp1',
#  'Tenm1',
#  'Pex19',
#  'Galnt2',
#  'Tbc1d2b',
#  'Trim26',
#  'Cphx1',
#  '5031434O11Rik',
#  'Btbd9',
#  'Trmo',
#  'Gm16233',
#  'Syt9',
#  'Ect2',
#  'Gatd1',
#  'Pcdhga3',
#  'Gm10110',
#  'Gm44550',
#  'Zscan25',
#  'Ovgp1',
#  'Mars2',
#  'Ska1',
#  'Rps19-ps6',
#  'Gm5527',
#  'Sdf2l1',
#  'Man2c1',
#  'Mettl4',
#  'Gm38340',
#  'Zfp61',
#  'Rpl3-ps2',
#  '2610028D06Rik',
#  'Phykpl',
#  'Zfp692',
#  'Arl4a',
#  'Nt5c',
#  'Gm8513',
#  'Mdc1',
#  'Zfp781',
#  'Ifit2',
#  '1600014C10Rik',
#  'Lrrc8d',
#  'Gm44913',
#  'Spaar',
#  'Gm29724',
#  '6330415G19Rik',
#  'Paip1',
#  'Ankrd50',
#  'Slc9b2',
#  'Flii',
#  'Hsbp1',
#  'Med13l',
#  'Cngb1',
#  'Tns3',
#  'Epb41l1',
#  'Commd5',
#  'Clk2',
#  'Gm15484',
#  'Gm41396',
#  'Snord3a',
#  'Fam160a1',
#  'H2ac1',
#  'Snai3',
#  'Macrod2',
#  'Slc25a26',
#  'Slc43a1',
#  'Kbtbd6',
#  'Tet1',
#  'Nedd4l',
#  'Ttc33',
#  'Snora41',
#  'Fbxl17',
#  'Rln1',
#  'Cptp',
#  'Gm26712',
#  'Hjurp',
#  'Ednra',
#  'Immp2l',
#  'Gm47599',
#  'Fndc3a',
#  'Fgfr2',
#  'Tle2',
#  'Fkbp7',
#  'Itgb3bp',
#  'Pnrc2',
#  'Pnmal2',
#  'Mpst',
#  'Plekhg4',
#  'P2rx4',
#  'Bod1l',
#  'Get3',
#  'Arhgap4',
#  'Zfas1',
#  'Gm35315',
#  'Skap2',
#  'Efna4',
#  'Stra6l',
#  'Gm47260',
#  'Kank2',
#  'Mrc2',
#  'Nrros',
#  'Arhgap31',
#  'Spry4',
#  'Gm26766',
#  'Ccnd1',
#  '4930558J22Rik',
#  'Rnf113a2',
#  'Tshz3',
#  'Lrrc29',
#  'Trim12c',
#  'Angptl6',
#  'Slc45a4',
#  'C1galt1',
#  '9530018F02Rik',
#  'Slc12a8',
#  'Vps26b',
#  'Ncl',
#  'Proser2',
#  'Srl',
#  '2310009B15Rik',
#  '4930519F16Rik',
#  'Lgals3',
#  'Atp6v1f',
#  'Anapc11',
#  'Cdkn2aip',
#  'Oaz1',
#  'Morc3',
#  'Il7',
#  'Mdk',
#  'Acly',
#  'Mccc1',
#  'Snrnp27',
#  'Ess2',
#  'Baz1a',
#  'Bbof1',
#  'Snhg12',
#  'Gm47398',
#  'Sh3bgr',
#  'Tpgs2',
#  'Ell2',
#  'Lpgat1',
#  'Ap3b2',
#  'Cdkn1b',
#  'Polr1c',
#  'Zfp971',
#  'Gm43457',
#  'Gm15351',
#  'Rab8a',
#  'Aip',
#  'Spag1',
#  'A930004J17Rik',
#  'Kctd7',
#  'Lmbrd2',
#  'Dennd3',
#  'Cdc42bpg',
#  'App',
#  'Add3',
#  'Ttc39a',
#  'Nrip3',
#  'Irak3',
#  'Pitx2',
#  'Fam50a',
#  'Ndufv1',
#  'Nudt18',
#  'Hps1',
#  'Nampt',
#  'Tbc1d5',
#  '1700030C10Rik',
#  'Epor',
#  'Zc3h14',
#  'Hap1',
#  'Romo1',
#  'Cacna1h',
#  'Usp19',
#  'Rpl37rt',
#  'Cstf1',
#  'Gm7059',
#  'Srarp',
#  'Snf8',
#  'Adgrg1',
#  'Ap1s3',
#  'Ddx6',
#  'Selenoo',
#  'B230354K17Rik',
#  'Rapgef2',
#  'Oas2',
#  'Rgmb',
#  'Zbtb40',
#  'Mturn',
#  'Uqcr11',
#  'Cops4',
#  'Gm37090',
#  'Aunip',
#  'Spata7',
#  'Gm6433',
#  'Lrrc4',
#  'Clba1',
#  'Nhs',
#  'Zfp68',
#  'Rhoq',
#  'Espl1',
#  'Eogt',
#  'Nkap',
#  'Phospho2',
#  'Edar',
#  'Nufip2',
#  'Lman2',
#  'Gm7143',
#  'Myo5a',
#  'Gm5786',
#  'Gm24455',
#  'Gapdh-ps16',
#  'Golm2',
#  'Gm50010',
#  'C9orf72',
#  'Exoc3l2',
#  'Glce',
#  'Kif5a',
#  'Gm13136',
#  'Mrps24',
#  'Tsga10ip',
#  'Gm5422',
#  'Gm42819',
#  'Porcn',
#  'Samd4',
#  'Acvr1',
#  'Tm7sf3',
#  'Bbc3',
#  'Mettl16',
#  'Tinagl1',
#  '2810002D19Rik',
#  'Myadm',
#  'Chp1',
#  'Kcna6',
#  'Clns1a',
#  'Gm45399',
#  'Gpr4',
#  'Syncrip',
#  '4930402H24Rik',
#  'Rpl13a',
#  'Wdr59',
#  'Pmaip1',
#  'Gm48643',
#  'Calcrl',
#  'Hook3',
#  'Coa3',
#  'Gm12790',
#  'Cnn2',
#  'Rbck1',
#  'Gm16023',
#  'Sv2a',
#  'Ldhc',
#  'Slc38a2',
#  'C230096K16Rik',
#  'Ncbp2',
#  'Hmgb3',
#  'Cyp39a1',
#  'Adamts1',
#  'Pfkp',
#  'Tcea1-ps1',
#  'Gpr37',
#  'Mtss2',
#  'Iftap',
#  'Shld2',
#  'Gm128',
#  'Gm45630',
#  'Chmp4c',
#  'Ndufs3',
#  'Ptms',
#  'Rbms1',
#  'Smpd1',
#  'Ccdc93',
#  'Rtn3',
#  'Golim4',
#  'Ralgps2',
#  'Smim26',
#  'Wdr62',
#  'Gmppa',
#  'Dedd2',
#  'Kctd6',
#  'Fam229b',
#  'Gm6166',
#  'Gm44552',
#  'Ap2m1',
#  'Nsg1',
#  'Gm4811',
#  'Gstp3',
#  '2610509F24Rik',
#  'Fxn',
#  'P2rx2',
#  'BC049715',
#  'Dnttip2',
#  'Pkn1',
#  'Atp5g3',
#  'Ccdc39',
#  'Cmc1',
#  'Lars2',
#  'Reep3',
#  'Zkscan8',
#  'Gm5112',
#  'Gm43653',
#  'Bri3bp',
#  'Secisbp2l',
#  'Utf1',
#  'Mtln',
#  'Bcl7b',
#  'Fbxl7',
#  '3110040N11Rik',
#  'Adamtsl5',
#  'Klhl10',
#  'Hdac10',
#  'Polr1e',
#  'Gm13110',
#  'Gm45605',
#  'Sf3b4',
#  'Ppp1r12b',
#  'Gm42467',
#  'Oma1',
#  '1110065P20Rik',
#  'Cilk1',
#  'Tmem229a',
#  'Vamp8',
#  'Immt',
#  'Gm3333',
#  'Tmbim4',
#  'Tma7-ps',
#  'Cdca7',
#  'Gnb5',
#  'Cyb5r1',
#  'Mga',
#  'Taf15',
#  'Gm17167',
#  'Gm36940',
#  'Cgas',
#  'Cntln',
#  'Zfp59',
#  'Gm12655',
#  'Chrac1',
#  'Shld3',
#  'Sclt1',
#  'Fam71e1',
#  'Syde2',
#  'Rad51b',
#  'Dtx3l',
#  'Smo',
#  'Cutc',
#  'Gm48375',
#  'Pam',
#  'Gm10330',
#  'Nop2',
#  'Hebp1',
#  'Diablo',
#  'Hsf2bp',
#  'Urah',
#  'Foxk2',
#  'Sez6l2',
#  'Ntf5',
#  'Cspg5',
#  'Ttc7',
#  'Mtmr11',
#  'Galt',
#  'Chrna7',
#  'Prxl2b',
#  'Bmpr1b',
#  'Gm14267',
#  'Adgrd1',
#  'Fam98b',
#  '4930566F21Rik',
#  'Tm2d2',
#  'Lpar2',
#  'Sirt4',
#  'Vdac3-ps1',
#  'Ywhag',
#  'Rbm44',
#  'Aif1l',
#  'Igsf9',
#  'Ttc30b',
#  'Qsox1',
#  'Napepld',
#  'Mapt',
#  'Gm43379',
#  'Slx4ip',
#  'Smarcc1',
#  'Cdh12',
#  'Tmem243',
#  'Polr1h',
#  'Eny2',
#  'Ndrg1',
#  'Htatsf1',
#  'Mtss1',
#  'Rab11fip3',
#  'Stmn2',
#  'Gm40040',
#  'Slc26a10',
#  'Gm44093',
#  'Map2k1',
#  'Rad51ap2',
#  'Gdf6',
#  'Pou6f1',
#  'Atg9b',
#  'Gm21596',
#  'Tmem208',
#  'ENSMUSG00002076451',
#  'Rps19-ps4',
#  'Amotl1',
#  'Ndrg3',
#  'Slc9a9',
#  'Tvp23a',
#  'Kank4os',
#  'Saa3',
#  'Gm22442',
#  'Mcur1',
#  'Tspan32',
#  'Arpin',
#  'Wnk1',
#  'Gm5796',
#  'Tmem116',
#  'Gabbr1',
#  'Igf2os',
#  'Mcu',
#  'Cct6a',
#  'Pcdh18',
#  'Fastkd3',
#  'Cops7b',
#  '2810454H06Rik',
#  'Dysf',
#  'Wnt7b',
#  'Adhfe1',
#  'Yif1a',
#  'R3hdm1',
#  'Snca',
#  'Neu3',
#  'Sertad3',
#  'Wdr46',
#  'Rcbtb2',
#  'Rpusd1',
#  'Rfx7',
#  'Efemp1',
#  'Lca5',
#  'Lrrc56',
#  'Prickle2',
#  'Cenpj',
#  'Phrf1',
#  '4833439L19Rik',
#  'Six4',
#  'S100a1',
#  'Fkbp10',
#  'Abl1',
#  'Zfp346',
#  'Dynlt1a',
#  'Enox2',
#  'Exosc10',
#  'Tyw1',
#  'Sdk1',
#  'Platr15',
#  'Gm5784',
#  'Rec114',
#  'Trappc8',
#  'Gm14124',
#  'Hdac6',
#  'Csf3r',
#  'Flad1',
#  'Igdcc4',
#  ...}

# %%
half_lifes = pd.read_excel('Data/half_life_data/41592_2017_BFnmeth4435_MOESM4_ESM.xls', sheet_name='global RNA half-lives', header=0)
half_lifes['Name'] = half_lifes['Name'].astype(str)
half_lifes = half_lifes[(half_lifes['Name'].isin(expressed_gene_names_set))]
half_lifes
# Out:
#      Chromosome      Start        End           Name  Length Strand  \
# 1          chr7  116104957  116105210  1110004F10Rik     253      +
# 4         chr15   76950480   76950979  1110038F14Rik     499      +
# 5         chr10   83762511   83762762  1500009L16Rik     251      +
# 7         chr17   14944679   14944990  1600012H06Rik     311      +
# 10        chr14   54690492   54690742  1700123O20Rik     250      +
# ...         ...        ...        ...            ...     ...    ...
# 6658       chrX  163952927  163953177          Zrsr2     250      -
# 6659      chr13   21442174   21442432        Zscan26     258      -
# 6660      chr11   62267223   62267482         Zswim7     259      -
# 6661       chr9   64137143   64137395         Zwilch     252      -
# 6662       chr4  108229730  108229980         Zyg11b     250      -
#
#       Half-life (h)  k (cpm/h)  stderror Half-life  stderror k   Rsquare
# 1          5.936154   0.116767            1.944206    0.056869  0.822637
# 4          3.212736   0.215750            0.714446    0.061699  0.894247
# 5          6.060218   0.114377            2.828555    0.100110  0.609735
# 7          2.282191   0.303720            0.715118    0.138600  0.736307
# 10         1.392595   0.497738            0.238069    0.102636  0.907563
# ...             ...        ...                 ...         ...       ...
# 6658       5.315421   0.130403            1.450899    0.048959  0.870613
# 6659       0.745045   0.930343            0.217440    0.383419  0.641365
# 6660       6.307095   0.109900            2.241834    0.060605  0.735318
# 6661       4.964903   0.139609            1.657282    0.069951  0.790147
# 6662       1.931063   0.358946            0.474268    0.116857  0.813993
#
# [6458 rows x 11 columns]

# %%
smoops_test = pd.read_excel('Results/Final_Submition_Files/masterfile_extended.xlsx')
smoops_test
# Out:
#        chr      start        end                gene_id     feature strand  \
# 0     chr1    3284704    3741721   ENSMUSG00000051951.6  transcript      -
# 1     chr1    3435953    3438772   ENSMUSG00000103377.2  transcript      -
# 2     chr1    3445778    3448011   ENSMUSG00000104017.2  transcript      -
# 3     chr1    3535199    3537508   ENSMUSG00000103025.2  transcript      -
# 4     chr1    3582673    3584730   ENSMUSG00000103201.2  transcript      -
# ...    ...        ...        ...                    ...         ...    ...
# 3055  chrX  160616291  160942726  ENSMUSG00000059493.14  transcript      -
# 3056  chrX  165173028  165223700   ENSMUSG00000040586.9  transcript      -
# 3057  chrX  168094525  168103276  ENSMUSG00000031352.11  transcript      -
# 3058  chrY    1260770    1286629  ENSMUSG00000069045.12  transcript      -
# 3059  chrM       1093       2675   ENSMUSG00000064339.1  transcript      +
#
#      gene_name          transcript_id  feature_length  smoops_naive  ...  \
# 0         Xkr4   ENSMUST00000070533.5          457017         False  ...
# 1      Gm37180   ENSMUST00000195335.2            2819         False  ...
# 2      Gm37363   ENSMUST00000192336.2            2233         False  ...
# 3      Gm37686   ENSMUST00000194099.2            2309         False  ...
# 4      Gm37329   ENSMUST00000192973.2            2057         False  ...
# ...        ...                    ...             ...           ...  ...
# 3055       Nhs  ENSMUST00000087085.10          326435         False  ...
# 3056      Ofd1   ENSMUST00000049501.9           50672         False  ...
# 3057      Hccs   ENSMUST00000033717.9            8751         False  ...
# 3058     Ddx3y  ENSMUST00000091190.12           25859         False  ...
# 3059   mt-Rnr2   ENSMUST00000082390.1            1582         False  ...
#
#       control_common  semi_diff_mean_tpm  semi_epiSC_mean_tpm  \
# 0              False            3.872970             2.324972
# 1              False            0.521827             0.301747
# 2              False            0.485116             0.206451
# 3              False            0.627143             0.321620
# 4              False            1.040409             0.393665
# ...              ...                 ...                  ...
# 3055           False            0.707368             0.917609
# 3056           False            2.596442             2.308879
# 3057            True            8.779636             9.323919
# 3058           False           12.061610             9.830595
# 3059           False          277.844274            47.457855
#
#       semi_naive_mean_tpm  semi_diff_mean_count  semi_epiSC_mean_count  \
# 0                0.014051            194.333000             235.666667
# 1                0.012481             22.666667              26.666667
# 2                0.000000             14.333333              15.666667
# 3                0.000000             18.000000              24.666667
# 4                0.000000             30.333333              25.333333
# ...                   ...                   ...                    ...
# 3055             0.077997             91.000000             245.000000
# 3056             1.399653            165.333333             326.725000
# 3057             9.318443            270.333333             630.333333
# 3058             1.813766            633.994667            1141.029333
# 3059            38.049362           5153.666667            2071.315667
#
#       semi_naive_mean_count  Cluster_x  Cluster_y       gene_type
# 0                  0.666667        NaN     C-rich  protein_coding
# 1                  0.333333        NaN   A/U-rich             TEC
# 2                  0.000000        NaN   A/U-rich             TEC
# 3                  0.000000        NaN   A/U-rich             TEC
# 4                  0.000000        NaN   A/U-rich             TEC
# ...                     ...        ...        ...             ...
# 3055               6.000000        NaN     C-rich  protein_coding
# 3056              86.666667        NaN   A/U-rich  protein_coding
# 3057             302.000333        NaN        NaN  protein_coding
# 3058              96.344667        NaN   A/U-rich  protein_coding
# 3059             742.666667        NaN   A/U-rich         Mt_rRNA
#
# [3060 rows x 22 columns]

# %%
masterfile = pd.read_csv('Data/masterfile/all_smOOPS_and_controls_V2.tsv', sep='\t')
masterfile["all_smoops"] = masterfile["smoops_naive"] | masterfile["smoops_epi"] | masterfile["smoops_diff"]
masterfile
# Out:
#        chr      start        end                gene_id     feature strand  \
# 0     chr1    3284704    3741721   ENSMUSG00000051951.6  transcript      -
# 1     chr1    3435953    3438772   ENSMUSG00000103377.2  transcript      -
# 2     chr1    3445778    3448011   ENSMUSG00000104017.2  transcript      -
# 3     chr1    3535199    3537508   ENSMUSG00000103025.2  transcript      -
# 4     chr1    3582673    3584730   ENSMUSG00000103201.2  transcript      -
# ...    ...        ...        ...                    ...         ...    ...
# 3055  chrX  160616291  160942726  ENSMUSG00000059493.14  transcript      -
# 3056  chrX  165173028  165223700   ENSMUSG00000040586.9  transcript      -
# 3057  chrX  168094525  168103276  ENSMUSG00000031352.11  transcript      -
# 3058  chrY    1260770    1286629  ENSMUSG00000069045.12  transcript      -
# 3059  chrM       1093       2675   ENSMUSG00000064339.1  transcript      +
#
#      gene_name          transcript_id  feature_length  smoops_naive  \
# 0         Xkr4   ENSMUST00000070533.5          457017         False
# 1      Gm37180   ENSMUST00000195335.2            2819         False
# 2      Gm37363   ENSMUST00000192336.2            2233         False
# 3      Gm37686   ENSMUST00000194099.2            2309         False
# 4      Gm37329   ENSMUST00000192973.2            2057         False
# ...        ...                    ...             ...           ...
# 3055       Nhs  ENSMUST00000087085.10          326435         False
# 3056      Ofd1   ENSMUST00000049501.9           50672         False
# 3057      Hccs   ENSMUST00000033717.9            8751         False
# 3058     Ddx3y  ENSMUST00000091190.12           25859         False
# 3059   mt-Rnr2   ENSMUST00000082390.1            1582         False
#
#       smoops_epi  smoops_diff  control_common  semi_diff_mean_tpm  \
# 0           True         True           False            3.872970
# 1           True         True           False            0.521827
# 2          False         True           False            0.485116
# 3          False         True           False            0.627143
# 4          False         True           False            1.040409
# ...          ...          ...             ...                 ...
# 3055        True         True           False            0.707368
# 3056        True         True           False            2.596442
# 3057       False        False            True            8.779636
# 3058        True         True           False           12.061610
# 3059       False         True           False          277.844274
#
#       semi_epiSC_mean_tpm  semi_naive_mean_tpm  semi_diff_mean_count  \
# 0                2.324972             0.014051            194.333000
# 1                0.301747             0.012481             22.666667
# 2                0.206451             0.000000             14.333333
# 3                0.321620             0.000000             18.000000
# 4                0.393665             0.000000             30.333333
# ...                   ...                  ...                   ...
# 3055             0.917609             0.077997             91.000000
# 3056             2.308879             1.399653            165.333333
# 3057             9.323919             9.318443            270.333333
# 3058             9.830595             1.813766            633.994667
# 3059            47.457855            38.049362           5153.666667
#
#       semi_epiSC_mean_count  semi_naive_mean_count  all_smoops
# 0                235.666667               0.666667        True
# 1                 26.666667               0.333333        True
# 2                 15.666667               0.000000        True
# 3                 24.666667               0.000000        True
# 4                 25.333333               0.000000        True
# ...                     ...                    ...         ...
# 3055             245.000000               6.000000        True
# 3056             326.725000              86.666667        True
# 3057             630.333333             302.000333       False
# 3058            1141.029333              96.344667        True
# 3059            2071.315667             742.666667        True
#
# [3060 rows x 20 columns]

# %%
clusters = pd.read_csv('Results/machine_learning_results/cluster_assignment_file/cluster_of_all_model.tsv', sep='\t')
clusters
# Out:
#               transcript_id  Cluster
# 0      ENSMUST00000000199.8        0
# 1      ENSMUST00000000291.9        0
# 2     ENSMUST00000000312.12        0
# 3     ENSMUST00000000314.13        0
# 4     ENSMUST00000000642.11        0
# ...                     ...      ...
# 1819   ENSMUST00000239449.2        0
# 1820   ENSMUST00000239483.2        0
# 1821   ENSMUST00000239525.1        0
# 1822   ENSMUST00000239527.1        0
# 1823   ENSMUST00000239552.1        0
#
# [1824 rows x 2 columns]

# %%
merged = pd.merge(half_lifes, masterfile, right_on='gene_name', left_on='Name', how='left')   
merged = pd.merge(merged, clusters, on='transcript_id', how='left')

merged = merged.rename(columns={'k (cpm/h)': 'k (cpm per h)'})

merged["naive_smoops_in_cluster0"] = (merged["Cluster"] == 0) & (merged["smoops_naive"])
merged["naive_smoops_in_cluster1"] = (merged["Cluster"] == 1) & (merged["smoops_naive"])

merged["non-smOOPs"] = ~merged["gene_name"].isin(set((masterfile[masterfile["smoops_naive"] == True]["gene_name"])))

print(merged["non-smOOPs"].value_counts())
print(merged["naive_smoops_in_cluster0"].sum())
print(merged["naive_smoops_in_cluster1"].sum())
merged
# Out:
# non-smOOPs
# True     6241
# False     217
# Name: count, dtype: int64
# 198
# 18
#      Chromosome      Start        End           Name  Length Strand  \
# 0          chr7  116104957  116105210  1110004F10Rik     253      +
# 1         chr15   76950480   76950979  1110038F14Rik     499      +
# 2         chr10   83762511   83762762  1500009L16Rik     251      +
# 3         chr17   14944679   14944990  1600012H06Rik     311      +
# 4         chr14   54690492   54690742  1700123O20Rik     250      +
# ...         ...        ...        ...            ...     ...    ...
# 6453       chrX  163952927  163953177          Zrsr2     250      -
# 6454      chr13   21442174   21442432        Zscan26     258      -
# 6455      chr11   62267223   62267482         Zswim7     259      -
# 6456       chr9   64137143   64137395         Zwilch     252      -
# 6457       chr4  108229730  108229980         Zyg11b     250      -
#
#       Half-life (h)  k (cpm per h)  stderror Half-life  stderror k  ...  \
# 0          5.936154       0.116767            1.944206    0.056869  ...
# 1          3.212736       0.215750            0.714446    0.061699  ...
# 2          6.060218       0.114377            2.828555    0.100110  ...
# 3          2.282191       0.303720            0.715118    0.138600  ...
# 4          1.392595       0.497738            0.238069    0.102636  ...
# ...             ...            ...                 ...         ...  ...
# 6453       5.315421       0.130403            1.450899    0.048959  ...
# 6454       0.745045       0.930343            0.217440    0.383419  ...
# 6455       6.307095       0.109900            2.241834    0.060605  ...
# 6456       4.964903       0.139609            1.657282    0.069951  ...
# 6457       1.931063       0.358946            0.474268    0.116857  ...
#
#       semi_epiSC_mean_tpm semi_naive_mean_tpm  semi_diff_mean_count  \
# 0                     NaN                 NaN                   NaN
# 1                     NaN                 NaN                   NaN
# 2                     NaN                 NaN                   NaN
# 3                     NaN                 NaN                   NaN
# 4                     NaN                 NaN                   NaN
# ...                   ...                 ...                   ...
# 6453                  NaN                 NaN                   NaN
# 6454                  NaN                 NaN                   NaN
# 6455                  NaN                 NaN                   NaN
# 6456            32.366821           37.650132            599.332667
# 6457                  NaN                 NaN                   NaN
#
#       semi_epiSC_mean_count semi_naive_mean_count all_smoops Cluster  \
# 0                       NaN                   NaN        NaN     NaN
# 1                       NaN                   NaN        NaN     NaN
# 2                       NaN                   NaN        NaN     NaN
# 3                       NaN                   NaN        NaN     NaN
# 4                       NaN                   NaN        NaN     NaN
# ...                     ...                   ...        ...     ...
# 6453                    NaN                   NaN        NaN     NaN
# 6454                    NaN                   NaN        NaN     NaN
# 6455                    NaN                   NaN        NaN     NaN
# 6456            1422.333667            755.999333      False     NaN
# 6457                    NaN                   NaN        NaN     NaN
#
#      naive_smoops_in_cluster0 naive_smoops_in_cluster1  non-smOOPs
# 0                       False                    False        True
# 1                       False                    False        True
# 2                       False                    False        True
# 3                       False                    False        True
# 4                       False                    False        True
# ...                       ...                      ...         ...
# 6453                    False                    False        True
# 6454                    False                    False        True
# 6455                    False                    False        True
# 6456                    False                    False        True
# 6457                    False                    False        True
#
# [6458 rows x 35 columns]

# %%
def plot_boxplot(df, value_column, control_column, compare_boolean_columns, log=False, stat_test='t-test'):

    df = df.copy()
    df = df[df[value_column].notna()]
    df[value_column] = df[value_column].astype(float)
    if log:
        df[f'log2({value_column} + 1e-6)'] = np.log2(df[value_column] + 1e-6)
        value_column = f'log2({value_column} + 1e-6)'

    conditions = [control_column] + compare_boolean_columns
    filtered_data = pd.DataFrame({
        condition: df[df[condition] == True][value_column] for condition in conditions
    })

    melted_data = filtered_data.melt(var_name='Condition', value_name=value_column)
    
    comparisons = [(control_column, condition) for condition in compare_boolean_columns]
    results = []
    for test_a, test_b in comparisons:
        test_a_data = filtered_data[test_a].dropna().to_list()
        test_b_data = filtered_data[test_b].dropna().to_list()
        print(f'{test_a}: {len(test_a_data)} data points, mean = {np.mean(test_a_data):.2f}')
        print(f'{test_b}: {len(test_b_data)} data points, mean = {np.mean(test_b_data):.2f}')
        if stat_test == 't-test':
            stat, p_val = ttest_ind(test_a_data, test_b_data, equal_var=False)
        elif stat_test == 'mannwhitneyu':
            stat, p_val = mannwhitneyu(test_a_data, test_b_data)
        results.append((test_a, test_b, p_val))
        print(f'{test_a} vs {test_b}: p-value = {p_val:.3f}')
        
    hex_palette = {control_column: '#bdcae2'}
    hex_palette.update({name: sns.color_palette('Set3')[idx] for idx, name in enumerate(compare_boolean_columns)})
    white_palette = {key: '#FFFFFF' for key in hex_palette.keys()}
    
    plt.figure(figsize=(len(compare_boolean_columns) * 0.5 + 2, 6))

    sns.violinplot(x='Condition', y=value_column, data=melted_data, palette=white_palette, inner=None, gap=0.3, zorder=0)

    ax = sns.boxplot(x='Condition', y=value_column, data=melted_data, palette=hex_palette, showfliers=False, width=0.15, whis=0, zorder=2)    
    
    y_max = melted_data[value_column].max() + 2
    y_step = y_max / 11

    for idx, (test_a, test_b, p_val) in enumerate(results):
        x1, x2 = conditions.index(test_a), conditions.index(test_b)
        y, h = y_max + idx * y_step, y_step / 4
        ax.plot([x1, x1, x2, x2], [y, y + h, y + h, y], lw=1.5, c='black')
        significance = "***" if p_val < 0.001 else "**" if p_val < 0.01 else "*" if p_val < 0.05 else "ns"
        ax.text((x1 + x2) * 0.5, y + h, significance, ha='center', va='bottom', color='black')
    
    plt.title(f'smOOPS {value_column} by Stage', fontsize=16)
    plt.ylabel(f'{value_column}', fontsize=14)
    plt.xticks(rotation=45, ha='right', fontsize=12)
    ax.set_xticklabels(conditions)

    legend_elements = [mpatches.Patch(color=hex_palette[name], label=name.replace('_', ' ').capitalize()) for name in hex_palette]
    plt.legend(handles=legend_elements, loc='upper right', bbox_to_anchor=(1.7, 1), frameon=False)
    sns.despine()
    plt.show()
    
plot_boxplot(merged, value_column='Half-life (h)', control_column='non-smOOPs', compare_boolean_columns=['naive_smoops_in_cluster0', 'naive_smoops_in_cluster1'], log=False, stat_test='mannwhitneyu')
plot_boxplot(merged, value_column='k (cpm per h)', control_column='non-smOOPs', compare_boolean_columns=['naive_smoops_in_cluster0', 'naive_smoops_in_cluster1'], log=False, stat_test='mannwhitneyu')
plot_boxplot(merged, value_column='Half-life (h)', control_column='non-smOOPs', compare_boolean_columns=['naive_smoops_in_cluster0', 'naive_smoops_in_cluster1'], log=True)
plot_boxplot(merged, value_column='k (cpm per h)', control_column='non-smOOPs', compare_boolean_columns=['naive_smoops_in_cluster0', 'naive_smoops_in_cluster1'], log=True)
# Out:
# non-smOOPs: 6241 data points, mean = 4.28
# naive_smoops_in_cluster0: 198 data points, mean = 3.73
# non-smOOPs vs naive_smoops_in_cluster0: p-value = 0.013
# non-smOOPs: 6241 data points, mean = 4.28
# naive_smoops_in_cluster1: 18 data points, mean = 3.85
# non-smOOPs vs naive_smoops_in_cluster1: p-value = 0.758
# /tmp/ipykernel_966053/3125083020.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y=value_column, data=melted_data, palette=white_palette, inner=None, gap=0.3, zorder=0)
# /tmp/ipykernel_966053/3125083020.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='Condition', y=value_column, data=melted_data, palette=hex_palette, showfliers=False, width=0.15, whis=0, zorder=2)
# /tmp/ipykernel_966053/3125083020.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(conditions)
# non-smOOPs: 6241 data points, mean = 0.21
# naive_smoops_in_cluster0: 198 data points, mean = 0.23
# non-smOOPs vs naive_smoops_in_cluster0: p-value = 0.013
# non-smOOPs: 6241 data points, mean = 0.21
# naive_smoops_in_cluster1: 18 data points, mean = 0.21
# non-smOOPs vs naive_smoops_in_cluster1: p-value = 0.758
# /tmp/ipykernel_966053/3125083020.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y=value_column, data=melted_data, palette=white_palette, inner=None, gap=0.3, zorder=0)
# /tmp/ipykernel_966053/3125083020.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='Condition', y=value_column, data=melted_data, palette=hex_palette, showfliers=False, width=0.15, whis=0, zorder=2)
# /tmp/ipykernel_966053/3125083020.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(conditions)
# non-smOOPs: 6241 data points, mean = 1.90
# naive_smoops_in_cluster0: 198 data points, mean = 1.76
# non-smOOPs vs naive_smoops_in_cluster0: p-value = 0.002
# non-smOOPs: 6241 data points, mean = 1.90
# naive_smoops_in_cluster1: 18 data points, mean = 1.83
# non-smOOPs vs naive_smoops_in_cluster1: p-value = 0.611
# /tmp/ipykernel_966053/3125083020.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y=value_column, data=melted_data, palette=white_palette, inner=None, gap=0.3, zorder=0)
# /tmp/ipykernel_966053/3125083020.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='Condition', y=value_column, data=melted_data, palette=hex_palette, showfliers=False, width=0.15, whis=0, zorder=2)
# /tmp/ipykernel_966053/3125083020.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(conditions)
# non-smOOPs: 6241 data points, mean = -2.43
# naive_smoops_in_cluster0: 198 data points, mean = -2.29
# non-smOOPs vs naive_smoops_in_cluster0: p-value = 0.002
# non-smOOPs: 6241 data points, mean = -2.43
# naive_smoops_in_cluster1: 18 data points, mean = -2.36
# non-smOOPs vs naive_smoops_in_cluster1: p-value = 0.611
# /tmp/ipykernel_966053/3125083020.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Condition', y=value_column, data=melted_data, palette=white_palette, inner=None, gap=0.3, zorder=0)
# /tmp/ipykernel_966053/3125083020.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(x='Condition', y=value_column, data=melted_data, palette=hex_palette, showfliers=False, width=0.15, whis=0, zorder=2)
# /tmp/ipykernel_966053/3125083020.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(conditions)
